# %% [markdown]
# 工程意识
# 1. 任何可能失败的地方，都要try/except（控制失败方式，而不是避免失败）
# 2. main.py只负责流程，逻辑放到utils/services
# 3. 一个项目至少2个python文件

# %% [markdown]
# Q：为什么要拆文件？
# A：明确职责边界、控制复杂度、隔离失败、并支撑后续的系统演进
