# %% [markdown]
# Day1

# %% [markdown]
# 安装 Python 3.10+；配置 venv；写 hello.py

# %%
# 终端运行python3 --version
# 报错 系统缺少Command Line Tools
“”“
xcode-select: note: No developer tools were found, requesting install.
If developer tools are located at a non-default location on disk, use `sudo xcode-select --switch path/to/Xcode.app` to specify the Xcode that you wish to use for command line developer tools, and cancel the installation dialog.
See `man xcode-select` for more details.
”“”

# %%
# 安装底层依赖
xcode-select --install

# %%
summer@danleideMacBook-Pro ~ % xcode-select -p
/Library/Developer/CommandLineTools

# %%
summer@danleideMacBook-Pro ~ % python3 --version
Python 3.9.6

# %%
# 配置虚拟环境
# python3 -m venv <name>
# 文件和venv虚拟环境同级
summer@danleideMacBook-Pro Phase1 % python3 -m venv agent-90-phase1
summer@danleideMacBook-Pro Phase1 % source agent-90-phase1/bin/activate

# %%
# 注册此环境为jupyter内核
(agent-90-phase1) summer@danleideMacBook-Pro Phase1 % python -m ipykernel install --user --name phase1 --display-name "phase1(agent-90-phase1)"
Installed kernelspec phase1 in /Users/summer/Library/Jupyter/kernels/phase1
