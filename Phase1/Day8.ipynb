# %% [markdown]
# FastAPI 文件上传
#
# 实现/uplaod_file接口，能成功接收文件

# %% [markdown]
# 浏览器 / 客户端
#
# -> HTTP POST
#
# -> multipart/form-data # 文件必须走body（multipart）
#
# -> FastAPI
#
# -> UploadFile 对象

# %%
# summer@danleideMacBook-Pro Agent_90days %
./.venv/bin/python -m uvicorn app.main:app --reload

"""
上传文件返回类似：
{
  "filename": "test.txt",
  "content_type": "text/plain"
}
"""
